# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
url = "https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Red%20Wine/winequality-red.csv"

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#to check shape
df.shape
# Out:
# (1599, 12)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#to check missing values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# We can observe that there are no null values present in dataset

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1359, 12)

# %% [markdown]
# All the duplicates values are removed from the dataset,
# After removing the duplicate values - Now we have ( 1359 rows, 12 Columns )

# %%
#to check the data
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# ...

# %% [markdown]
# 1. There are no missing values
# 2. Mean is more than Median - that means positive skewed
# 3. There is more difference between 75% & Max Values for residual sugar, Free sulfur dioxide, Total sulfur dioxode.

# %%
df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.171231          0.578596     0.244523        2.509532
# 6             8.337383          0.496084     0.279364        2.457290
# 7             8.858683          0.403653     0.371856        2.716766
# 8             8.441176          0.427647     0.382941        2.576471
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.093971            17.161179             57.406412  0.997082
# 6         0.085075            15.637383             40.816822  0.996565
# 7         0.076832            13.994012             35.449102  0.996051
# ...

# %%
#data visualization
plt.figure(figsize=(20, 15))
p=1
for i in df.columns[:-1]:
    if p <= 12:
        plt.subplot(4, 3, p)
        sns.catplot(x='quality', y=i, kind='bar', data=df, height=4, aspect=1.5)
        plt.title(f'Barplot of {i} vs. Wine Quality')
        plt.xlabel('Wine Quality')
        plt.ylabel(i)
        p += 1
        
    plt.tight_layout()
    plt.show()

# %%
# Correlation between target variable and Independent Variable
dfcor = df.corr()
dfcor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
# to check the skewness in the data
dfskew = df.skew()
dfskew
# Out:
# fixed acidity           0.941041
# volatile acidity        0.729279
# citric acid             0.312726
# residual sugar          4.548153
# chlorides               5.502487
# free sulfur dioxide     1.226579
# total sulfur dioxide    1.540368
# density                 0.044778
# pH                      0.232032
# sulphates               2.406505
# alcohol                 0.859841
# quality                 0.192407
# dtype: float64

# %%
# lets visualize the skewness
plt.figure(figsize=(20, 15))
p=1
for i in df.columns[:-1]:
    if p <= 12:
        plt.subplot(4, 3, p)
        sns.histplot( data=df, x= i, kde = True)
        plt.xticks()
        plt.title(f'Distribution of {i}')
        plt.xlabel(i)
        p += 1
        
    plt.tight_layout()
    plt.show()

# %%
# checking for outliers in the data
plt.figure(figsize=(20, 15))
p=1
for i in df.columns:
    if p <= 12:
        plt.subplot(4, 3, p)
        sns.boxplot( data=df, x= df[i])
        plt.xticks()
        plt.xlabel(i)
        p += 1
        
    plt.tight_layout()
    plt.show()

# %% [markdown]
# We can see the outliers present in all the columns

# %%
# we can remove the skewness of the data using powertransform
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer()

df2 = pt.fit_transform(df.iloc[:,:-1])
df2 = pd.DataFrame(df2, columns = df.iloc[:,:-1].columns)
df2.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.439412          0.978091    -1.530544       -0.602600  -0.166676
# 1      -0.161475          1.720040    -1.530544        0.560720   0.778512
# 2      -0.161475          1.242047    -1.256962        0.153076   0.557116
# 3       1.529010         -1.551503     1.389613       -0.602600  -0.219369
# 4      -0.439412          0.791661    -1.530544       -0.844564  -0.219369
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.269573             -0.128948  0.587781  1.277041  -0.582775
# 1             0.992495              0.841796  0.054350 -0.695907   0.400130
# 2             0.192377              0.530012  0.161294 -0.296058   0.188379
# 3             0.384096              0.681966  0.694083 -0.967619  -0.391438
# 4            -0.023152              0.100926  0.587781  1.277041  -0.582775
#
#     alcohol
# 0 -1.068157
# 1 -0.499290
# 2 -0.499290
# ...

# %%
df2.skew()
# Out:
# fixed acidity           0.001884
# volatile acidity        0.008311
# citric acid             0.016563
# residual sugar         -0.001715
# chlorides              -0.061923
# free sulfur dioxide    -0.009899
# total sulfur dioxide   -0.003897
# density                -0.002812
# pH                     -0.005007
# sulphates               0.014637
# alcohol                 0.116742
# dtype: float64

# %%
#lets visualize
plt.figure(figsize=(20, 15))
p=1
for i in df.columns[:-1]:
    if p <= 12:
        plt.subplot(4, 3, p)
        sns.histplot( data=df, x= i, kde = True)
        plt.xticks()
        plt.title(f'Distribution of {i}')
        plt.xlabel(i)
        p += 1
        
    plt.tight_layout()
    plt.show()

# %% [markdown]
# We can observe that skewness in the data is removed

# %% [markdown]
# # Classifying the wine quality as good or bad based on quality

# %%
# "Bad" or 0 if quality of wine lies in range of (3 to 6)
#"Good" or 1 if the quality of wine lies in range 7 or above 7

# lets add target variable in new dataframe, based the quality

df2['quality'] = df['quality'].apply(lambda x:1 if x>6 else 0)
df2.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.439412          0.978091    -1.530544       -0.602600  -0.166676
# 1      -0.161475          1.720040    -1.530544        0.560720   0.778512
# 2      -0.161475          1.242047    -1.256962        0.153076   0.557116
# 3       1.529010         -1.551503     1.389613       -0.602600  -0.219369
# 4      -0.439412          0.791661    -1.530544       -0.844564  -0.219369
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.269573             -0.128948  0.587781  1.277041  -0.582775
# 1             0.992495              0.841796  0.054350 -0.695907   0.400130
# 2             0.192377              0.530012  0.161294 -0.296058   0.188379
# 3             0.384096              0.681966  0.694083 -0.967619  -0.391438
# 4            -0.023152              0.100926  0.587781  1.277041  -0.582775
#
#     alcohol  quality
# 0 -1.068157      0.0
# ...

# %%
# Checking current value count of quality variable now
print(df2['quality'].value_counts())
sns.countplot(x='quality', data=df2)
plt.show()
# Out:
# 0.0    989
# 1.0    163
# Name: quality, dtype: int64

# %% [markdown]
# We can observe that bad quality wine is more than good quality wine

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
x = df.drop('quality',axis = 1)
y = df['quality']
for i in range(0,500):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=i)
    lr = LogisticRegression()
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)== round (accuracy_score(y_test,pred_test)*100,1):
        print('random state:',i)
        print("training r2_score",accuracy_score(y_train,pred_train)*100)
        print("testing r2_score",accuracy_score(y_test,pred_test)*100)
# Out:
# random state: 108
# training r2_score 43.7902483900644
# testing r2_score 43.75
# random state: 121
# training r2_score 44.06623735050598
# testing r2_score 44.11764705882353
# random state: 147
# training r2_score 42.594296228150874
# testing r2_score 42.64705882352941
# random state: 431
# training r2_score 43.7902483900644
# testing r2_score 43.75

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=121)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        10
#            5       0.42      0.79      0.54       113
#            6       0.49      0.25      0.33       113
#            7       0.00      0.00      0.00        28
#            8       0.00      0.00      0.00         6
#
#     accuracy                           0.43       272
#    macro avg       0.15      0.17      0.15       272
# weighted avg       0.38      0.43      0.36       272

# %%
pred_lr = lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)
lss
print("Accuracy Score", lss*100)
# Out:
# Accuracy Score 43.01470588235294

# %%
#to save the model
import pickle
filename = 'Red_Wine_Quality_Prediction_Project.pkl'
pickle.dump(lr,open(filename,'wb'))

# %%
#loading Model
load_model=pickle.load(open('Red_Wine_Quality_Prediction_Project.pkl','rb'))
result=load_model.score(x_test,y_test)
print(result*100)
# Out:
# 43.01470588235294
